# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import tensorflow.compat.v1 as tf

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
tmp = df['Close'] == df['Adj Close']

# %%
tmp.unique()
# Out:
# array([ True])

# %%
from collections import deque
import random


class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# <ipython-input-9-9934fc4f9176>:26: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
# /home/myihbach/anaconda3/lib/python3.8/site-packages/keras/legacy_tf_layers/core.py:255: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   return layer.apply(inputs)
# <ipython-input-9-9934fc4f9176>:27: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.logits = tf.layers.dense(feed, self.action_size)
# epoch: 10, total rewards: 785.975217.3, cost: 0.886697, total money: 8883.205197
# epoch: 20, total rewards: 256.995236.3, cost: 0.526849, total money: 9267.745236
# epoch: 30, total rewards: 362.405148.3, cost: 0.298408, total money: 7440.995113
# epoch: 40, total rewards: 441.705075.3, cost: 0.232833, total money: 7560.045040
# epoch: 50, total rewards: 491.805234.3, cost: 0.179270, total money: 7610.145199
# epoch: 60, total rewards: 414.625180.3, cost: 0.145469, total money: 7532.965145
# epoch: 70, total rewards: 401.210020.3, cost: 0.110980, total money: 8433.070005
# epoch: 80, total rewards: 405.749936.3, cost: 0.199628, total money: 7602.859922
# epoch: 90, total rewards: 415.570066.3, cost: 0.091755, total money: 7533.910031
# epoch: 100, total rewards: 362.640193.3, cost: 0.117667, total money: 10362.640193
# epoch: 110, total rewards: 270.620114.3, cost: 0.356087, total money: 10270.620114
# epoch: 120, total rewards: 275.580135.3, cost: 0.117517, total money: 10275.580135
# epoch: 130, total rewards: 158.910092.3, cost: 0.043218, total money: 9169.660092
# epoch: 140, total rewards: 417.370053.3, cost: 0.042704, total money: 9428.120053
# epoch: 150, total rewards: 456.310056.3, cost: 0.042539, total money: 9467.060056
# epoch: 160, total rewards: 454.950009.3, cost: 0.040116, total money: 8522.789974
# epoch: 170, total rewards: 370.670041.3, cost: 0.070676, total money: 10370.670041
# epoch: 180, total rewards: 435.960081.3, cost: 0.026760, total money: 8467.820066
# epoch: 190, total rewards: 500.740110.3, cost: 0.024986, total money: 9511.490110
# epoch: 200, total rewards: 362.360105.3, cost: 0.047302, total money: 10362.360105

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 2: buy 1 unit at price 762.020020, total balance 9237.979980
# day 3: buy 1 unit at price 782.520020, total balance 8455.459960
# day 4, sell 1 unit at price 790.510010, investment 3.738746 %, total balance 9245.969970,
# day 6, sell 1 unit at price 762.559998, investment -2.550736 %, total balance 10008.529968,
# day 9: buy 1 unit at price 758.489990, total balance 9250.039978
# day 14: buy 1 unit at price 768.270020, total balance 8481.769958
# day 15, sell 1 unit at price 760.989990, investment 0.329602 %, total balance 9242.759948,
# day 16: buy 1 unit at price 761.679993, total balance 8481.079955
# day 17, sell 1 unit at price 768.239990, investment -0.003909 %, total balance 9249.319945,
# day 18: buy 1 unit at price 770.840027, total balance 8478.479918
# day 19, sell 1 unit at price 758.039978, investment -0.477893 %, total balance 9236.519896,
# day 22, sell 1 unit at price 762.520020, investment -1.079343 %, total balance 9999.039916,
# day 24: buy 1 unit at price 771.190002, total balance 9227.849914
# day 25, sell 1 unit at price 776.419983, investment 0.678170 %, total balance 10004.269897,
# day 29: buy 1 unit at price 797.070007, total balance 9207.199890
# day 30: buy 1 unit at price 797.849976, total balance 8409.349914
# day 31, sell 1 unit at price 790.799988, investment -0.786633 %, total balance 9200.149902,
# day 32, sell 1 unit at price 794.200012, investment -0.457475 %, total balance 9994.349914,
# day 35: buy 1 unit at price 791.260010, total balance 9203.089904
# day 37: buy 1 unit at price 791.549988, total balance 8411.539916
# day 38, sell 1 unit at price 785.049988, investment -0.784827 %, total balance 9196.589904,
# day 41, sell 1 unit at price 786.140015, investment -0.683466 %, total balance 9982.729919,
# day 43: buy 1 unit at price 794.020020, total balance 9188.709899
# day 45, sell 1 unit at price 806.650024, investment 1.590640 %, total balance 9995.359923,
# day 49: buy 1 unit at price 807.880005, total balance 9187.479918
# day 50: buy 1 unit at price 804.609985, total balance 8382.869933
# day 53, sell 1 unit at price 805.020020, investment -0.354011 %, total balance 9187.889953,
# day 54: buy 1 unit at price 819.309998, total balance 8368.579955
# day 58, sell 1 unit at price 823.309998, investment 2.324109 %, total balance 9191.889953,
# day 60, sell 1 unit at price 796.789978, investment -2.748657 %, total balance 9988.679931,
# day 65: buy 1 unit at price 806.969971, total balance 9181.709960
# day 66, sell 1 unit at price 808.380005, investment 0.174732 %, total balance 9990.089965,
# day 67: buy 1 unit at price 809.559998, total balance 9180.529967
# day 68, sell 1 unit at price 813.669983, investment 0.507681 %, total balance 9994.199950,
# day 73: buy 1 unit at price 828.070007, total balance 9166.129943
# day 75: buy 1 unit at price 830.760010, total balance 8335.369933
# day 76, sell 1 unit at price 831.330017, investment 0.393688 %, total balance 9166.699950,
# day 77: buy 1 unit at price 828.640015, total balance 8338.059935
# day 79, sell 1 unit at price 823.210022, investment -0.908805 %, total balance 9161.269957,
# day 82: buy 1 unit at price 829.080017, total balance 8332.189940
# day 84, sell 1 unit at price 831.909973, investment 0.394617 %, total balance 9164.099913,
# day 87, sell 1 unit at price 843.250000, investment 1.709121 %, total balance 10007.349913,
# day 90: buy 1 unit at price 847.200012, total balance 9160.149901
# day 91: buy 1 unit at price 848.780029, total balance 8311.369872
# day 92, sell 1 unit at price 852.119995, investment 0.580735 %, total balance 9163.489867,
# day 93: buy 1 unit at price 848.400024, total balance 8315.089843
# day 94, sell 1 unit at price 830.460022, investment -2.158393 %, total balance 9145.549865,
# day 96, sell 1 unit at price 817.580017, investment -3.632721 %, total balance 9963.129882,
# day 104: buy 1 unit at price 834.570007, total balance 9128.559875
# day 105: buy 1 unit at price 831.409973, total balance 8297.149902
# day 106: buy 1 unit at price 827.880005, total balance 7469.269897
# day 107, sell 1 unit at price 824.669983, investment -1.186242 %, total balance 8293.939880,
# day 109: buy 1 unit at price 823.349976, total balance 7470.589904
# day 111: buy 1 unit at price 823.559998, total balance 6647.029906
# day 112: buy 1 unit at price 837.169983, total balance 5809.859923
# day 113, sell 1 unit at price 836.820007, investment 0.650706 %, total balance 6646.679930,
# day 114: buy 1 unit at price 838.210022, total balance 5808.469908
# day 115, sell 1 unit at price 841.650024, investment 1.663287 %, total balance 6650.119932,
# day 116: buy 1 unit at price 843.190002, total balance 5806.929930
# day 119: buy 1 unit at price 871.729980, total balance 4935.199950
# day 121: buy 1 unit at price 905.960022, total balance 4029.239928
# day 122, sell 1 unit at price 912.570007, investment 10.836222 %, total balance 4941.809935,
# day 124: buy 1 unit at price 927.039978, total balance 4014.769957
# day 125, sell 1 unit at price 931.659973, investment 13.125938 %, total balance 4946.429930,
# day 128, sell 1 unit at price 932.169983, investment 11.347755 %, total balance 5878.599913,
# day 134, sell 1 unit at price 919.619995, investment 9.712360 %, total balance 6798.219908,
# day 136, sell 1 unit at price 934.010010, investment 10.771002 %, total balance 7732.229918,
# day 137, sell 1 unit at price 941.859985, investment 8.044923 %, total balance 8674.089903,
# day 138: buy 1 unit at price 948.820007, total balance 7725.269896
# day 139, sell 1 unit at price 954.960022, investment 5.408627 %, total balance 8680.229918,
# day 140, sell 1 unit at price 969.539978, investment 4.584484 %, total balance 9649.769896,
# day 141, sell 1 unit at price 971.469971, investment 2.387172 %, total balance 10621.239867,
# day 142: buy 1 unit at price 975.880005, total balance 9645.359862
# day 143: buy 1 unit at price 964.859985, total balance 8680.499877
# day 144, sell 1 unit at price 966.950012, investment -0.915071 %, total balance 9647.449889,
# day 145: buy 1 unit at price 975.599976, total balance 8671.849913
# day 148: buy 1 unit at price 980.940002, total balance 7690.909911
# day 149: buy 1 unit at price 983.409973, total balance 6707.499938
# day 152, sell 1 unit at price 953.400024, investment -1.187733 %, total balance 7660.899962,
# day 154, sell 1 unit at price 942.309998, investment -3.412257 %, total balance 8603.209960,
# day 155, sell 1 unit at price 939.780029, investment -4.195973 %, total balance 9542.989989,
# day 157: buy 1 unit at price 950.630005, total balance 8592.359984
# day 159, sell 1 unit at price 957.090027, investment -2.676396 %, total balance 9549.450011,
# day 160, sell 1 unit at price 965.590027, investment 1.573696 %, total balance 10515.040038,
# day 161: buy 1 unit at price 952.270020, total balance 9562.770018
# day 163: buy 1 unit at price 940.489990, total balance 8622.280028
# day 164, sell 1 unit at price 917.789978, investment -3.620826 %, total balance 9540.070006,
# day 165: buy 1 unit at price 908.729980, total balance 8631.340026
# day 166: buy 1 unit at price 898.700012, total balance 7732.640014
# day 167, sell 1 unit at price 911.710022, investment -3.060104 %, total balance 8644.350036,
# day 171, sell 1 unit at price 930.090027, investment 2.350538 %, total balance 9574.440063,
# day 172: buy 1 unit at price 943.830017, total balance 8630.610046
# day 173: buy 1 unit at price 947.159973, total balance 7683.450073
# day 174: buy 1 unit at price 955.989990, total balance 6727.460083
# day 177: buy 1 unit at price 970.890015, total balance 5756.570068
# day 180: buy 1 unit at price 980.340027, total balance 4776.230041
# day 182: buy 1 unit at price 947.799988, total balance 3828.430053
# day 187, sell 1 unit at price 930.390015, investment 3.526205 %, total balance 4758.820068,
# day 191, sell 1 unit at price 926.789978, investment -1.805414 %, total balance 5685.610046,
# day 192, sell 1 unit at price 922.900024, investment -2.561336 %, total balance 6608.510070,
# day 193, sell 1 unit at price 907.239990, investment -5.099426 %, total balance 7515.750060,
# day 194: buy 1 unit at price 914.390015, total balance 6601.360045
# day 195: buy 1 unit at price 922.669983, total balance 5678.690062
# day 197: buy 1 unit at price 926.960022, total balance 4751.730040
# day 199, sell 1 unit at price 910.669983, investment -6.202560 %, total balance 5662.400023,
# day 200, sell 1 unit at price 906.659973, investment -7.515765 %, total balance 6569.059996,
# day 201, sell 1 unit at price 924.690002, investment -2.438277 %, total balance 7493.749998,
# day 202, sell 1 unit at price 927.000000, investment 1.379060 %, total balance 8420.749998,
# day 203: buy 1 unit at price 921.280029, total balance 7499.469969
# day 204, sell 1 unit at price 915.890015, investment -0.734820 %, total balance 8415.359984,
# day 205: buy 1 unit at price 913.809998, total balance 7501.549986
# day 206: buy 1 unit at price 921.289978, total balance 6580.260008
# day 208: buy 1 unit at price 939.330017, total balance 5640.929991
# day 209, sell 1 unit at price 937.340027, investment 1.119790 %, total balance 6578.270018,
# day 213: buy 1 unit at price 926.500000, total balance 5651.770018
# day 214: buy 1 unit at price 929.080017, total balance 4722.690001
# day 216, sell 1 unit at price 935.090027, investment 1.499001 %, total balance 5657.780028,
# day 219, sell 1 unit at price 915.000000, investment 0.130224 %, total balance 6572.780028,
# day 221, sell 1 unit at price 931.580017, investment 1.116916 %, total balance 7504.360045,
# day 222, sell 1 unit at price 932.450012, investment -0.732437 %, total balance 8436.810057,
# day 223: buy 1 unit at price 928.530029, total balance 7508.280028
# day 225: buy 1 unit at price 924.859985, total balance 6583.420043
# day 226, sell 1 unit at price 944.489990, investment 1.941715 %, total balance 7527.910033,
# day 227: buy 1 unit at price 949.500000, total balance 6578.410033
# day 229: buy 1 unit at price 953.270020, total balance 5625.140013
# day 233, sell 1 unit at price 978.890015, investment 5.361217 %, total balance 6604.030028,
# day 236: buy 1 unit at price 989.250000, total balance 5614.780028
# day 237, sell 1 unit at price 987.830017, investment 6.386437 %, total balance 6602.610045,
# day 240, sell 1 unit at price 992.179993, investment 7.278940 %, total balance 7594.790038,
# day 242, sell 1 unit at price 984.450012, investment 3.680886 %, total balance 8579.240050,
# day 243, sell 1 unit at price 988.200012, investment 3.664229 %, total balance 9567.440062,
# day 245, sell 1 unit at price 970.539978, investment -1.891334 %, total balance 10537.980040,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
